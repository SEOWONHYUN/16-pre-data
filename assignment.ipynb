# %%
2. 위에서 부터 밑으로 컴파일 언어보다 이해하기 쉬운게 파이썬 인터프리터 언어

4.python --version

6.python-->대화형 모드

8.>>>-->파이썬 입력

10.python hello.py---->py를 실행하는 명령어 이거 중요하다 교수님 강조

11.cd(change directory)
python test.py

., ./->현재 폴더
.., ../->상위 폴더  ../  ../ 상위폴더의 상위폴더
/\ 폴더 구분자

integrated development Environment

추출 []대괄호 쓰는거 잊지 말기

문자열 시작은 0부터 시작이다 -->중요

끝나는 지점이 공백이면 바로 앞에 값까지 나온다-->중요

만약 끝나는 지점 생략시 끝까지 나옴
