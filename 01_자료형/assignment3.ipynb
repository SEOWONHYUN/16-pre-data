# %%
#tuple1 = (1,2,3,4,5) --> 튜플 생성 
#튜플 수정 삭제 x

#리스트는 변할 수 있다!
#set함수는 중복 허용 x 순서도 없다
#s2 = {}
#type(s2) ----> 이거 dic
#s3 = set()
#type(s3)
# Out:
#   Cell In[1], line 7
#     "이름"= "서원현"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
