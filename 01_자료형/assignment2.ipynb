# %%
#1.이메일 주소에서 아이디만 추출하는 코드 hint(find, 슬라이싱)

email = "test123@gmail.com"

idx = email.find("@")
email[:idx]
# Out:
# 'test123'

# %%
filename="report.pdf"
idx = filename.find(".")
ext = filename[idx + 1:]
print(ext)
# Out:
# pdf

# %%
#3. 전체 기이 공백 제거 길이 대문자로 변환 단어 개수 특ㄱ정 단어 포함 여부

#text=~~~
#print("전체 길이:",len(text))
#print("공백 제거 길이:", len(text.replace(" " ---> 이거 공백임,"")))
#print("대문자:",upper(text))
#text.split()--> list 형식의 요소로 나눈다
#len(text.split())---> 요소로 나누기 
#print("python 포함 여부:","python" in text)

#'python' in text --> in 연산자 -->존재하는가?

# %%
#부터 10까지 리스트
#list=[1,2,3,4,5,6,7,8,9,1-]
#list2=["apple", "banana", "cherry"]
#empty1=[]
#empty2 =list()

#정수 실수 문자열 생성

# 10 3.14 "Python"

#print(len(~~~), type(~~~))

# %%
#슬라이싱

#처음 3개 요소 print(numbers[:3])
#마지막 3개 요소 print(numbers[-3:])
#인덱스 2부터 6까지 6포함 print(numbers[2:7])
#짝수만 print(numbers[::2]) [::3]을 하면 3칸 띄어줌
#print(numbers[:]) --> 이건 전체 나오는거
#리스트 역순으로 print(numbers[::-1])
#print(numbers[4:0:-1])--> 이러면 4부터 내려가면서 역순으로 0까지
#1부터 8까지 2칸식 건너뛰면 print(numbers[1:9:2])

# %%
#리스트 연산자
# 리스트 + 사용해서 연결시키기
# 3번 반복은 *3
# 5가 있는지 없는지? print(5 in [1,2,3])
# 리스트 ["a", "b", "c"]에서 요소 "b"가 없는지 확인하시오
# print("b" not in ["a","b","c"]
# 두 리스트가 같은지 비교하시오(==)
#print([1,2,3] == [1,2,3])

# %%
#리스트는 수정이 가능하다 튜플과 다르게 

#data = [10, 20, 30, 40, 50]

#인덱스 2의 값을 100으로 변경
#data[2] = 100
#print(data)
#0qnxj 2Rkwlfmf [1,2,3]으로 변경
#data[0:3] = [1,2,3]
#del data[1] ---> del은 삭제

# %%
#내장 함수 이용 max min --> 얘들은 집계함수 
#sorted --->오름 차순 정렬
#print(sorted(scores, reverse =True))-->이건 오름 차순 해서 reverse로 뒤집어서 다시 내림차순으로 정렬하는거

# %%
#리스트와 문자열

#text = "Hello World"
#print(list(text))
# text2 = "a,b,c,d,e"
#print(text2.split(","))
#words = ["Python", "is", "fun"]
#print(" ".join(words))
#extend는 결합 느낌 append랑은 다르다!

# %%
#removed =items.pop()-->이거 기본값이 -1이다
#clear는 모든 요소 제거

#print(data.count(5))
#print(data.index(5))-->인덱스 찾기

# %%
#튜플은 하나의 요소 반드시t3 = [1,]와 같이 
#  수정과 삭제가 안된다
